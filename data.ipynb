# %%
import pandas as pd

data = [
   ["Flu","fever","cough","headache"],
    ["Migraine","headache","nausea","vomiting"],
    ["Dengue","fever","joint_pain","rash"],
    ["Malaria","fever","chills","shivering"],
    ["Typhoid","high_fever","weakness","abdominal_pain"],
    ["Common Cold","cough","sneezing","runny_nose"],
    ["COVID-19","fever","cough","breathlessness"],
    ["Pneumonia","fever","cough","chest_pain"],
    ["Asthma","breathlessness","chest_tightness","cough"],
    ["Bronchitis","cough","fatigue","shortness_of_breath"],
    ["Chickenpox","fever","rash","itching"],
    ["Measles","fever","rash","red_eyes"],
    ["Diabetes","frequent_urination","increased_thirst","fatigue"],
    ["Hypertension","headache","dizziness","chest_pain"],
    ["Heart Disease","chest_pain","breathlessness","fatigue"],
    ["Gastritis","stomach_pain","nausea","vomiting"],
    ["Food Poisoning","vomiting","diarrhea","stomach_pain"],
    ["Tuberculosis","cough","weight_loss","night_sweats"],
    ["Allergy","sneezing","itching","runny_nose"],
    ["Sinusitis","headache","facial_pain","nasal_congestion"],
    ["Anemia","fatigue","pale_skin","shortness_of_breath"],
    ["Depression","sadness","fatigue","sleep_problems"],
    ["Arthritis","joint_pain","stiffness","swelling"],
    ["Kidney Stones","back_pain","vomiting","painful_urination"],
    ["Liver Disease","fatigue","abdominal_pain","yellowing_skin"]
]

df = pd.DataFrame(data, columns=["Disease","Symptom1","Symptom2","Symptom3"])
df.to_csv("dataset.csv", index=False)

# %%
import pandas as pd

data = [
["Flu","Take rest","Drink fluids","Consult doctor"],
["Migraine","Avoid stress","Take rest","Use medication"],
["Dengue","Drink fluids","Take rest","Consult doctor"],
["Malaria","Use mosquito nets","Take medication","Avoid stagnant water"],
["Typhoid","Drink clean water","Maintain hygiene","Take antibiotics"],
["Common Cold","Drink warm fluids","Take rest","Avoid cold exposure"],
["COVID-19","Wear mask","Isolate","Consult doctor"],
["Pneumonia","Take antibiotics","Rest well","Consult doctor"],
["Asthma","Avoid triggers","Use inhaler","Consult doctor"],
["Bronchitis","Avoid smoke","Take rest","Drink fluids"],
["Chickenpox","Avoid scratching","Take rest","Maintain hygiene"],
["Measles","Isolate patient","Take rest","Consult doctor"],
["Diabetes","Monitor sugar","Exercise regularly","Follow diet"],
["Hypertension","Reduce salt","Exercise","Monitor BP"],
["Heart Disease","Avoid stress","Healthy diet","Regular checkup"],
["Gastritis","Avoid spicy food","Eat small meals","Take medication"],
["Food Poisoning","Drink fluids","Rest","Consult doctor"],
["Tuberculosis","Complete medication","Avoid crowd","Consult doctor"],
["Allergy","Avoid allergens","Take antihistamines","Consult doctor"],
["Sinusitis","Steam inhalation","Drink fluids","Take medication"],
["Anemia","Iron rich diet","Take supplements","Consult doctor"],
["Depression","Seek support","Exercise","Consult therapist"],
["Arthritis","Exercise","Physiotherapy","Take medication"],
["Kidney Stones","Drink water","Avoid salty food","Consult doctor"],
["Liver Disease","Avoid alcohol","Healthy diet","Consult doctor"]
]

df = pd.DataFrame(data, columns=["Disease","Precaution1","Precaution2","Precaution3"])
df.to_csv("symptom_precaution.csv", index=False)

print("✅ symptom_precaution.csv created!")
# Out:
# ✅ symptom_precaution.csv created!

# %%
import pandas as pd

data = [
["Flu","Flu is a viral infection causing fever cough and headache"],
["Migraine","Migraine is a neurological condition causing severe headaches nausea and vomiting"],
["Dengue","Dengue is a mosquito borne viral infection causing fever joint pain and rash"],
["Malaria","Malaria is caused by parasites transmitted through mosquito bites leading to fever chills and shivering"],
["Typhoid","Typhoid is a bacterial infection causing high fever weakness and abdominal pain"],
["Common Cold","Common cold is a viral infection causing cough sneezing and runny nose"],
["COVID-19","COVID-19 is a viral respiratory illness causing fever cough and breathing issues"],
["Pneumonia","Pneumonia is a lung infection causing fever cough and chest pain"],
["Asthma","Asthma is a chronic condition causing breathing difficulty and chest tightness"],
["Bronchitis","Bronchitis is inflammation of airways causing cough fatigue and breathlessness"],
["Chickenpox","Chickenpox is a viral infection causing fever rash and itching"],
["Measles","Measles is a contagious viral disease causing fever rash and red eyes"],
["Diabetes","Diabetes is a metabolic disorder causing increased thirst urination and fatigue"],
["Hypertension","Hypertension is high blood pressure causing headache dizziness and chest pain"],
["Heart Disease","Heart disease affects heart function causing chest pain and breathlessness"],
["Gastritis","Gastritis is inflammation of stomach lining causing pain nausea and vomiting"],
["Food Poisoning","Food poisoning occurs due to contaminated food causing vomiting diarrhea and stomach pain"],
["Tuberculosis","Tuberculosis is a bacterial infection affecting lungs causing cough and weight loss"],
["Allergy","Allergy is immune response causing sneezing itching and runny nose"],
["Sinusitis","Sinusitis is inflammation of sinuses causing headache and nasal congestion"],
["Anemia","Anemia is a condition with low red blood cells causing fatigue and pale skin"],
["Depression","Depression is a mental health disorder causing sadness fatigue and sleep issues"],
["Arthritis","Arthritis causes joint pain stiffness and swelling"],
["Kidney Stones","Kidney stones are hard deposits causing severe back pain and vomiting"],
["Liver Disease","Liver disease affects liver causing fatigue abdominal pain and yellow skin"]
]

df = pd.DataFrame(data, columns=["Disease","Description"])
df.to_csv("symptom_Description.csv", index=False)

print("✅ symptom_Description.csv created!")
# Out:
# ✅ symptom_Description.csv created!
