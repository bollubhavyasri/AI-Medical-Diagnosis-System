# %%
import pandas as pd
df_rules = pd.read_csv("dataset.csv")
print(df_rules)
#df_desc = pd.read_csv("symptom_Description.csv")
#df_prec = pd.read_csv("symptom_precaution.csv")
# Out:
#            Disease            Symptom1          Symptom2             Symptom3
# 0              Flu               fever             cough             headache
# 1         Migraine            headache            nausea             vomiting
# 2           Dengue               fever        joint_pain                 rash
# 3          Malaria               fever            chills            shivering
# 4          Typhoid          high_fever          weakness       abdominal_pain
# 5      Common Cold               cough          sneezing           runny_nose
# 6         COVID-19               fever             cough       breathlessness
# 7        Pneumonia               fever             cough           chest_pain
# 8           Asthma      breathlessness   chest_tightness                cough
# 9       Bronchitis               cough           fatigue  shortness_of_breath
# 10      Chickenpox               fever              rash              itching
# 11         Measles               fever              rash             red_eyes
# 12        Diabetes  frequent_urination  increased_thirst              fatigue
# 13    Hypertension            headache         dizziness           chest_pain
# 14   Heart Disease          chest_pain    breathlessness              fatigue
# 15       Gastritis        stomach_pain            nausea             vomiting
# 16  Food Poisoning            vomiting          diarrhea         stomach_pain
# 17    Tuberculosis               cough       weight_loss         night_sweats
# 18         Allergy            sneezing           itching           runny_nose
# 19       Sinusitis            headache       facial_pain     nasal_congestion
# 20          Anemia             fatigue         pale_skin  shortness_of_breath
# 21      Depression             sadness           fatigue       sleep_problems
# 22       Arthritis          joint_pain         stiffness             swelling
# 23   Kidney Stones           back_pain          vomiting    painful_urination
# 24   Liver Disease             fatigue    abdominal_pain       yellowing_skin

# %%
import pandas as pd

df_desc = pd.read_csv("symptom_Description.csv")
print(df_desc)
# Out:
#            Disease                                        Description
# 0              Flu  Flu is a viral infection causing fever cough a...
# 1         Migraine  Migraine is a neurological condition causing s...
# 2           Dengue  Dengue is a mosquito borne viral infection cau...
# 3          Malaria  Malaria is caused by parasites transmitted thr...
# 4          Typhoid  Typhoid is a bacterial infection causing high ...
# 5      Common Cold  Common cold is a viral infection causing cough...
# 6         COVID-19  COVID-19 is a viral respiratory illness causin...
# 7        Pneumonia  Pneumonia is a lung infection causing fever co...
# 8           Asthma  Asthma is a chronic condition causing breathin...
# 9       Bronchitis  Bronchitis is inflammation of airways causing ...
# 10      Chickenpox  Chickenpox is a viral infection causing fever ...
# 11         Measles  Measles is a contagious viral disease causing ...
# 12        Diabetes  Diabetes is a metabolic disorder causing incre...
# 13    Hypertension  Hypertension is high blood pressure causing he...
# 14   Heart Disease  Heart disease affects heart function causing c...
# 15       Gastritis  Gastritis is inflammation of stomach lining ca...
# 16  Food Poisoning  Food poisoning occurs due to contaminated food...
# 17    Tuberculosis  Tuberculosis is a bacterial infection affectin...
# 18         Allergy  Allergy is immune response causing sneezing it...
# 19       Sinusitis  Sinusitis is inflammation of sinuses causing h...
# 20          Anemia  Anemia is a condition with low red blood cells...
# 21      Depression  Depression is a mental health disorder causing...
# 22       Arthritis  Arthritis causes joint pain stiffness and swel...
# 23   Kidney Stones  Kidney stones are hard deposits causing severe...
# 24   Liver Disease  Liver disease affects liver causing fatigue ab...

# %%
import pandas as pd

df_prec = pd.read_csv("symptom_precaution.csv")
print(df_prec)
# Out:
#            Disease          Precaution1          Precaution2  \
# 0              Flu            Take rest         Drink fluids
# 1         Migraine         Avoid stress            Take rest
# 2           Dengue         Drink fluids            Take rest
# 3          Malaria    Use mosquito nets      Take medication
# 4          Typhoid    Drink clean water     Maintain hygiene
# 5      Common Cold    Drink warm fluids            Take rest
# 6         COVID-19            Wear mask              Isolate
# 7        Pneumonia     Take antibiotics            Rest well
# 8           Asthma       Avoid triggers          Use inhaler
# 9       Bronchitis          Avoid smoke            Take rest
# 10      Chickenpox     Avoid scratching            Take rest
# 11         Measles      Isolate patient            Take rest
# 12        Diabetes        Monitor sugar   Exercise regularly
# 13    Hypertension          Reduce salt             Exercise
# 14   Heart Disease         Avoid stress         Healthy diet
# 15       Gastritis     Avoid spicy food      Eat small meals
# 16  Food Poisoning         Drink fluids                 Rest
# 17    Tuberculosis  Complete medication          Avoid crowd
# 18         Allergy      Avoid allergens  Take antihistamines
# 19       Sinusitis     Steam inhalation         Drink fluids
# 20          Anemia       Iron rich diet     Take supplements
# 21      Depression         Seek support             Exercise
# 22       Arthritis             Exercise        Physiotherapy
# 23   Kidney Stones          Drink water     Avoid salty food
# 24   Liver Disease        Avoid alcohol         Healthy diet
#
#              Precaution3
# 0         Consult doctor
# 1         Use medication
# 2         Consult doctor
# 3   Avoid stagnant water
# 4       Take antibiotics
# 5    Avoid cold exposure
# 6         Consult doctor
# 7         Consult doctor
# 8         Consult doctor
# 9           Drink fluids
# 10      Maintain hygiene
# 11        Consult doctor
# 12           Follow diet
# 13            Monitor BP
# 14       Regular checkup
# 15       Take medication
# 16        Consult doctor
# 17        Consult doctor
# 18        Consult doctor
# 19       Take medication
# 20        Consult doctor
# 21     Consult therapist
# 22       Take medication
# 23        Consult doctor
# 24        Consult doctor
